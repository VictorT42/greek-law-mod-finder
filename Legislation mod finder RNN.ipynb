# %%
pip install --user sklearn

# %%
import pickle
import csv
import numpy as np
import sklearn
import tensorflow as tf
from tensorflow.keras.layers import Input, Masking, Bidirectional as Bi, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import SGD, RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam
from IPython.display import display, HTML
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from random import sample
import os.path

f = open("vectorized.pickle","rb")
v = pickle.load(f)

# %%
labels = ['none', 'gazette', 'law', 'target fragment', 'new fragment', 'date', 'mod type (deprecated)',
         'mod body', 'mod type: addition', 'mod type: deletion', 'mod type: update', 'mod type: date change', 'mod type: renumbering']
def print_preds(doc, preds):
    colors=['white','#5b0f00','#a61c00','#ff0000','#0000ff','#6aa84f','#b45f06','#e69138','#b45f06','#b45f06','#b45f06','#b45f06','#b45f06','#b45f06']
    with open('toks3.p','rb') as f:
        toks=pickle.load(f)
    output=''
    for i in range(min(input_length, len(toks[doc]['tokens']))):
        if preds[i] == 0:
            output+=toks[doc]['tokens'][i]+' '
        else:
            output+='<span style="color:white; background-color:'+colors[preds[i]]+'">'+toks[doc]['tokens'][i]+' </span>'
    display(HTML(output))

# %%
input_length = 300
test_size = 100
keep_all = False

if keep_all:
    n = input_length
    sep_docs = list()
    for doc in v:
        wv = [doc['word_vectors'][i * n:(i + 1) * n] for i in range((len(doc['word_vectors']) + n - 1) // n )]
        l = [doc['labels'][i * n:(i + 1) * n] for i in range((len(doc['labels']) + n - 1) // n )]
        sep_docs += [{'word_vectors':wv[i],'labels':l[i]} for i in range(len(wv))]
    v = sep_docs

unpadded_x = np.array([np.array(doc['word_vectors']) for doc in v])
#y=np.array([np.array(doc['labels']) for doc in v])
unpadded_y = list()
for doc in v:
    a = np.array(doc['labels'])
    b = np.zeros((a.size, 13))
    b[np.arange(a.size),a] = 1
    unpadded_y.append(b)
unpadded_y = np.array(unpadded_y)

x = tf.keras.preprocessing.sequence.pad_sequences(
    unpadded_x,
    maxlen = input_length,
    dtype = 'float32',
    padding = 'post',
    truncating = 'post',
    value = 0.0
)
y = tf.keras.preprocessing.sequence.pad_sequences(
    unpadded_y,
    maxlen = input_length,
    dtype = 'float32',
    padding = 'post',
    truncating = 'post',
    value = 100.0
)

#test_index = sample(range(len(x)), test_size)
f = open('test_index.pickle','rb')
test_index = pickle.load(f)
f.close()
x_test = np.array([x[i] for i in test_index])
y_test = np.array([y[i] for i in test_index])
x_train_val = np.array([x[i] for i in range(len(x)) if i not in test_index])
y_train_val = np.array([y[i] for i in range(len(y)) if i not in test_index])

kf = KFold(n_splits=5, shuffle=True, random_state=10)

# %%
def create_model(optimizer=Adam(), dropout_rate=0.1, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
                 init_mode=tf.keras.initializers.GlorotUniform, weight_constraint=None, neurons=100):
    model = tf.keras.models.Sequential([
        Input((input_length, 100), batch_size=None),
        Masking(),
        Bi(LSTM(neurons, dropout=dropout_rate, kernel_initializer=init_mode(), kernel_constraint=weight_constraint, return_sequences=True)),
        Bi(LSTM(neurons, dropout=dropout_rate, kernel_initializer=init_mode(), kernel_constraint=weight_constraint, return_sequences=True)),
        Dropout(rate=dropout_rate),
        Dense(13, activation='softmax')
    ])

    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.CategoricalCrossentropy(),
                  metrics=metrics)

    return model

# %%
# define the grid search parameters
# fit parameters
batch_size_values = [None, 16, 32, 64, 128]
epochs_values = [10, 50, 100]
# optimizer
optimizer_values = [SGD, RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam]
learning_rate_values = [0.001, 0.01, 0.1, 0.2, 0.3]
momentum_values = [0.0, 0.2, 0.4, 0.6, 0.8, 0.9]
# architecture
init_mode_values = [tf.keras.initializers.Ones, tf.keras.initializers.Zeros, tf.keras.initializers.GlorotNormal, tf.keras.initializers.GlorotUniform]
weight_constraint_values = [None, tf.keras.constraints.MinMaxNorm(),tf.keras.constraints.NonNeg(),tf.keras.constraints.UnitNorm()]
dropout_rate_values = [0.001, 0.01, 0.2, 0.5]
neurons_values = [50, 100, 150]
#param_grid_values = dict(batch_size=batch_size, epochs=epochs)
#metrics
def f1(precision, recall):
    return 2*(recall * precision)/(recall + precision)
metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]

# %%
batch_size=32
epochs=50
optimizer=RMSprop
init_mode=tf.keras.initializers.GlorotUniform
weight_constraint=tf.keras.constraints.MinMaxNorm()
neurons=100
dropout_rate=0.01

# %%
# fit
for batch_size in batch_size_values:
    file_name = f'./output/batch_size_{batch_size}.pickle'
    if os.path.isfile(file_name):
        continue
    fit_results = [['batch_size', 'epochs', 'loss', 'accuracy', 'precision']]
    for epochs in epochs_values:
        for train_index, val_index in kf.split(x_train_val, y_train_val):
            print(batch_size, epochs)
            x_train, x_val = x_train_val[train_index], x_train_val[val_index]
            y_train, y_val = y_train_val[train_index], y_train_val[val_index]
            model = create_model()
            model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
            fit_results.append([batch_size, epochs] + model.evaluate(x_val,y_val))
    f=open(file_name, 'wb')
    pickle.dump(fit_results, f)
    f.close()

# %%
# optimizer
for optimizer in optimizer_values:
    file_name = f'./output/optimizer_{optimizer}.pickle'
    if os.path.isfile(file_name):
        continue
    fit_results = [['optimizer','loss','accuracy','precision']]
    for train_index, val_index in kf.split(x_train_val, y_train_val):
        print(optimizer)
        x_train, x_val = x_train_val[train_index], x_train_val[val_index]
        y_train, y_val = y_train_val[train_index], y_train_val[val_index]
        model = create_model(optimizer=optimizer())
        model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
        fit_results.append([str(optimizer)] + model.evaluate(x_val,y_val))
    f=open(file_name, 'wb')
    pickle.dump(fit_results, f)
    f.close()

# %%
# architecture
for init_mode in init_mode_values:
    file_name = f'./output/init_mode_{str(init_mode)}.csv'
    if os.path.isfile(file_name):
        continue
    fit_results = [['init mode','weight constraint','loss','accuracy','precision']]
    for weight_constraint in weight_constraint_values:
        for train_index, val_index in kf.split(x_train_val, y_train_val):
            print(init_mode)
            x_train, x_val = x_train_val[train_index], x_train_val[val_index]
            y_train, y_val = y_train_val[train_index], y_train_val[val_index]
            model = create_model(optimizer=optimizer(),init_mode=init_mode,weight_constraint=weight_constraint)
            model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
            fit_results.append([str(init_mode), str(weight_constraint)] + model.evaluate(x_val,y_val))
    f=open(file_name, 'w')
    c=csv.writer(f)
    c.writerows(fit_results)
    f.close()

# %%
# architecture 2
for neurons in neurons_values:
    file_name = f'./output/neurons_{neurons}.csv'
    if os.path.isfile(file_name):
        continue
    fit_results = [['neurons','dropout','loss','accuracy','precision','recall']]
    for dropout_rate in dropout_rate_values:
        for train_index, val_index in kf.split(x_train_val, y_train_val):
            print(neurons)
            x_train, x_val = x_train_val[train_index], x_train_val[val_index]
            y_train, y_val = y_train_val[train_index], y_train_val[val_index]
            model = create_model(optimizer=optimizer(),init_mode=init_mode,weight_constraint=weight_constraint,dropout_rate=dropout_rate,neurons=neurons)
            model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
            fit_results.append([str(neurons), str(dropout_rate)] + model.evaluate(x_val,y_val))
    f=open(file_name, 'w')
    c=csv.writer(f)
    c.writerows(fit_results)
    f.close()

# %%
# optimizer params
for momentum in momentum_values:
    file_name = f'./output/momentum_{momentum}.csv'
    if os.path.isfile(file_name):
        continue
    fit_results = [['momentum','learning_rate','loss','accuracy','precision','recall']]
    for learning_rate in learning_rate_values:
        for train_index, val_index in kf.split(x_train_val, y_train_val):
            print(momentum, learning_rate)
            x_train, x_val = x_train_val[train_index], x_train_val[val_index]
            y_train, y_val = y_train_val[train_index], y_train_val[val_index]
            model = create_model(optimizer=optimizer(learning_rate=learning_rate, momentum=momentum),
                                 init_mode=init_mode,weight_constraint=weight_constraint,
                                 dropout_rate=dropout_rate,neurons=neurons)
            model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
            fit_results.append([str(momentum), str(learning_rate)] + model.evaluate(x_val,y_val))
    f=open(file_name, 'w')
    c=csv.writer(f)
    c.writerows(fit_results)
    f.close()

# %%
model = create_model(weight_constraint=weight_constraint,dropout_rate=dropout_rate,optimizer=optimizer())
model.fit(x_train_val,y_train_val,epochs=epochs,batch_size=batch_size)
# Out:
# Train on 433 samples
# Epoch 1/50
# 433/433 [==============================] - 10s 24ms/sample - loss: 0.7146 - accuracy: 0.6716 - precision: 0.7825 - recall: 0.5495
# Epoch 2/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.4425 - accuracy: 0.7825 - precision: 0.8208 - recall: 0.7386
# Epoch 3/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.3636 - accuracy: 0.8181 - precision: 0.8429 - recall: 0.7861
# Epoch 4/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.3147 - accuracy: 0.8418 - precision: 0.8577 - recall: 0.8190
# Epoch 5/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.2733 - accuracy: 0.8494 - precision: 0.8609 - recall: 0.8343
# Epoch 6/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.2208 - accuracy: 0.8885 - precision: 0.8973 - recall: 0.8770
# Epoch 7/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.1551 - accuracy: 0.9321 - precision: 0.9384 - recall: 0.9241
# Epoch 8/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.1533 - accuracy: 0.9356 - precision: 0.9402 - recall: 0.9296
# Epoch 9/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.1180 - accuracy: 0.9522 - precision: 0.9564 - recall: 0.9474
# Epoch 10/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.1494 - accuracy: 0.9351 - precision: 0.9397 - recall: 0.9300
# Epoch 11/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0822 - accuracy: 0.9663 - precision: 0.9695 - recall: 0.9626
# Epoch 12/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0734 - accuracy: 0.9714 - precision: 0.9743 - recall: 0.9683
# Epoch 13/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0502 - accuracy: 0.9808 - precision: 0.9833 - recall: 0.9784
# Epoch 14/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0881 - accuracy: 0.9703 - precision: 0.9730 - recall: 0.9679
# Epoch 15/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0412 - accuracy: 0.9849 - precision: 0.9871 - recall: 0.9831
# Epoch 16/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0312 - accuracy: 0.9882 - precision: 0.9901 - recall: 0.9864
# Epoch 17/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0337 - accuracy: 0.9864 - precision: 0.9885 - recall: 0.9847
# Epoch 18/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0228 - accuracy: 0.9911 - precision: 0.9923 - recall: 0.9897
# Epoch 19/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0364 - accuracy: 0.9857 - precision: 0.9872 - recall: 0.9844
# Epoch 20/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0189 - accuracy: 0.9929 - precision: 0.9939 - recall: 0.9920
# Epoch 21/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0191 - accuracy: 0.9923 - precision: 0.9933 - recall: 0.9912
# Epoch 22/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0156 - accuracy: 0.9938 - precision: 0.9946 - recall: 0.9932
# Epoch 23/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0359 - accuracy: 0.9890 - precision: 0.9900 - recall: 0.9880
# Epoch 24/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0148 - accuracy: 0.9942 - precision: 0.9949 - recall: 0.9936
# Epoch 25/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0122 - accuracy: 0.9953 - precision: 0.9959 - recall: 0.9947
# Epoch 26/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0112 - accuracy: 0.9960 - precision: 0.9963 - recall: 0.9955
# Epoch 27/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0189 - accuracy: 0.9920 - precision: 0.9929 - recall: 0.9913
# Epoch 28/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0264 - accuracy: 0.9933 - precision: 0.9937 - recall: 0.9930
# Epoch 29/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0082 - accuracy: 0.9974 - precision: 0.9976 - recall: 0.9971
# Epoch 30/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0077 - accuracy: 0.9973 - precision: 0.9975 - recall: 0.9971
# Epoch 31/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0071 - accuracy: 0.9975 - precision: 0.9977 - recall: 0.9972
# Epoch 32/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0122 - accuracy: 0.9948 - precision: 0.9950 - recall: 0.9944
# Epoch 33/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0054 - accuracy: 0.9983 - precision: 0.9984 - recall: 0.9980
# Epoch 34/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0058 - accuracy: 0.9981 - precision: 0.9983 - recall: 0.9979
# Epoch 35/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0048 - accuracy: 0.9984 - precision: 0.9985 - recall: 0.9982
# Epoch 36/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0087 - accuracy: 0.9964 - precision: 0.9965 - recall: 0.9962
# Epoch 37/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0037 - accuracy: 0.9988 - precision: 0.9989 - recall: 0.9987
# Epoch 38/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0266 - accuracy: 0.9930 - precision: 0.9933 - recall: 0.9928
# Epoch 39/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0034 - accuracy: 0.9989 - precision: 0.9990 - recall: 0.9988
# Epoch 40/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0025 - accuracy: 0.9993 - precision: 0.9994 - recall: 0.9992
# Epoch 41/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0029 - accuracy: 0.9991 - precision: 0.9991 - recall: 0.9991
# Epoch 42/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0032 - accuracy: 0.9987 - precision: 0.9988 - recall: 0.9987
# Epoch 43/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0053 - accuracy: 0.9978 - precision: 0.9979 - recall: 0.9976
# Epoch 44/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0040 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9983
# Epoch 45/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0022 - accuracy: 0.9994 - precision: 0.9994 - recall: 0.9994
# Epoch 46/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0017 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9995
# Epoch 47/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0025 - accuracy: 0.9991 - precision: 0.9992 - recall: 0.9991
# Epoch 48/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0577 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9897
# Epoch 49/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0014 - accuracy: 0.9997 - precision: 0.9997 - recall: 0.9997
# Epoch 50/50
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0012 - accuracy: 0.9997 - precision: 0.9997 - recall: 0.9997

# %%
model.evaluate(x_test,y_test)

# %%
x_i,y_i=kf.split(x_train_val,y_train_val)
model.evaluate(x_train_val[x_,y_train)

# %%
y_predictions = model.predict(x_test)
pred_labels = list()
for doc in y_predictions:
    newdoc = list()
    for label in doc:
        newdoc.append(np.argmax(label))
    pred_labels.append(newdoc)

# %%
true_labels = list()
for j in range(len(y_predictions)):
    true_labels = true_labels + [np.argmax(i) for i in y_test[j]]

# %%
predicted_labels = list()
for j in range(len(y_predictions)):
    predicted_labels = predicted_labels + [np.argmax(i) for i in y_predictions[j]]

# %%
print(sklearn.metrics.confusion_matrix(true_labels,predicted_labels, labels=range(13)))

# %%
print(sklearn.metrics.classification_report(true_labels,predicted_labels))

# %%
a=sklearn.metrics.classification_report(true_labels,predicted_labels)

# %%
with open('toks3.p','rb') as f:
    toks=pickle.load(f)

# %%
for i in range(len(v)):
    for j in range(len(v[i]["labels"])):
        if v[i]["labels"][j] > 7:
            print(toks[i]["tokens"][j]," ",v[i]["labels"][j])

# %%
for i in range(len(test_index)):
    print_preds(test_index[i],pred_labels[i])
# Out:
# ΑΡΘΡΟ d
#  d. ΣΤΗΝ <span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#a61c00">, </span>ΤΟ <span style="color:white; background-color:#ff0000">ΤΕΛΕΥΤΑΙΟ </span><span style="color:white; background-color:#ff0000">ΕΔΑΦΙΟ </span><span style="color:white; background-color:#ff0000">ΤΗΣ </span><span style="color:white; background-color:#ff0000">ΠΕΡΙΠΤΩΣΗΣ </span><span style="color:white; background-color:#ff0000">Γ΄ </span><span style="color:white; background-color:#ff0000">ΥΠΟΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#ff0000">II </span><span style="color:white; background-color:#b45f06">ΔΙΑΓΡΑΦΕΤΑΙ </span><span style="color:white; background-color:#b45f06">. </span>
#  d. Η <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΔΗΛΩΣΕΙΣ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΟΥΣΙΑΚΗΣ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΣΤΑΣΗΣ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΠΡΟΣΩΠΩΝ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΑΝΑΦΕΡΟΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΙΣ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΠΤΩΣΕΙΣ </span><span style="color:white; background-color:#e69138">ΣΤ΄ </span><span style="color:white; background-color:#e69138">ΕΩΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΙΕ΄ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΡ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΠΑΡΟΝΤΟΣ </span><span style="color:white; background-color:#e69138">ΝΟΜΟΥ </span><span style="color:white; background-color:#e69138">ΥΠΟΒΑΛΛΟΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΗ </span><span style="color:white; background-color:#e69138">Γ΄ </span><span style="color:white; background-color:#e69138">ΜΟΝΑΔΑ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΑΡΧΗΣ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">Ν </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">dddd/dddd </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">
#  </span>d. ΣΤΗΝ <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#a61c00">, </span>Η <span style="color:white; background-color:#ff0000">ΦΡΑΣΗ </span><span style="color:white; background-color:#ff0000">« </span><span style="color:white; background-color:#ff0000">ΑΠΟ </span><span style="color:white; background-color:#ff0000">ΤΙΣ </span><span style="color:white; background-color:#ff0000">ΕΠΙΤΡΟΠΕΣ </span><span style="color:white; background-color:#ff0000">ΤΩΝ </span><span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΩΝ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΚΑΙ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">ΑΥΤΟΥ </span><span style="color:white; background-color:#ff0000">, </span><span style="color:white; background-color:#ff0000">ΤΟΣΟ </span><span style="color:white; background-color:#ff0000">ΟΙ </span><span style="color:white; background-color:#ff0000">ΙΔΙΕΣ </span><span style="color:white; background-color:#ff0000">» </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΑΠΟ ΤΗ <span style="color:white; background-color:#0000ff">ΦΡΑΣΗ </span><span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΕΠΙΤΡΟΠΗ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΡΑΓΡΑΦΟΥ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΤΟΣΟ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΙΔΙΑ </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">. </span>
#  d. Η <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#b45f06">ΑΝ
# ΑΡΘΡΟ dd
#  ΑΠΑΣΧΟΛΗΣΗ ΣΥΝΤΑΞΙΟΥΧΩΝ ΚΑΙ ΛΟΙΠΕΣ ΔΙΑΤΑΞΕΙΣ
#  d. ΟΙ ΔΙΑΤΑΞΕΙΣ ΤΟΥ ΑΡΘΡΟΥ dd ΤΟΥ Ν . dddd/dddd ( Α΄ d) ΟΠΩΣ ΑΥΤΟ ΙΣΧΥΕΙ ΜΕΤΑ ΤΗΝ ΑΝΤΙΚΑΤΑΣΤΑΣΗ ΤΟΥ ΜΕ ΤΗΝ ΠΑΡ . d ΤΟΥ ΑΡΘΡΟΥ dd ΤΟΥ Ν . dddd/dddd ( Α΄ ddd ) , ΚΑΘΩΣ ΚΑΙ ΚΑΤΑΣΤΑΤΙΚΕΣ ΔΙΑΤΑΞΕΙΣ ΠΟΥ ΠΡΟΒΛΕΠΟΥΝ ΑΝΑΣΤΟΛΗ ΚΑΤΑΒΟΛΗΣ ΤΗΣ ΣΥΝΤΑΞΗΣ ΓΗΡΑΤΟΣ Η ΑΝΑΠΗΡΙΑΣ ΣΕ ΠΕΡΙΠΤΩΣΗ ΠΟΥ Ο ΣΥΝΤΑΞΙΟΥΧΟΣ ΑΝΑΛΑΜΒΑΝΕΙ ΕΡΓΑΣΙΑ Η ΑΥΤΟΑΠΑΣΧΟΛΕΙΤΑΙ ΚΑΙ ΥΠΑΓΕΤΑΙ ΣΤΗΝ ΑΣΦΑΛΙΣΗ ΤΟΥ ΦΟΡΕΑ ΑΠΟ ΤΟΝ ΟΠΟΙΟ ΣΥΝΤΑΞΙΟΔΟΤΕΙΤΑΙ , ΔΕΝ ΕΧΟΥΝ ΕΦΑΡΜΟΓΗ ΣΤΟΥΣ ΣΥΝΤΑΞΙΟΥΧΟΥΣ ΑΣΦΑΛΙΣΤΙΚΩΝ ΟΡΓΑΝΙΣΜΩΝ ΑΡΜΟΔΙΟΤΗΤΑΣ ΤΟΥ ΥΠΟΥΡΓΕΙΟΥ ΕΡΓΑΣΙΑΣ ΚΑΙ ΚΟΙΝΩΝΙΚΗΣ ΑΣΦΑΛΙΣΗΣ , ΠΟΥ ΕΧΟΥΝ ΣΥΝΤΑΞΙΟΔΟΤΗΘΕΙ ΜΕ ΤΙΣ ΔΙΑΤΑΞΕΙΣ ΤΟΥ Ν . ddd/dddd , ΟΠΩΣ ΙΣΧΥΕΙ , ΚΑΙ ΣΤΟΥΣ ΣΥΝΤΑΞΙΟΥΧΟΥΣ ΠΟΥ ΛΑΜΒΑΝΟΥΝ ΤΟ ΕΞΩΙΔΡΥΜΑΤΙΚΟ ΕΠΙΔΟΜΑ .
#  d. ΣΤΗΝ <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span>( <span style="color:white; background-color:#5b0f00">Α΄d </span><span style="color:white; background-color:#5b0f00">) </span>ΟΠΩΣ ΑΝΤΙΚΑΤΑΣΤΑΘΗΚΕ ΜΕ ΤΗΝ ΠΑΡ . d ΤΟΥ ΑΡΘΡΟΥ dd ΤΟΥ Ν . dddd/dddd ( Α΄ddd ) <span style="color:white; background-color:#b45f06">ΠΡΟΣΤΙΘΕΤΑΙ </span><span style="color:white; background-color:#0000ff">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#0000ff">ΣΤ΄ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">ΣΤ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΣΤΟΥΣ </span><span style="color:white; background-color:#e69138">ΣΥΝΤΑΞΙΟΥΧΟΥΣ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΝΑΥΤΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΑΠΟΜΑΧΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΤΑΜΕΙΟΥ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΠΑΡΕΧΟΥΝ </span><span style="color:white; background-color:#e69138">ΕΚΠΑΙΔΕΥΤΙΚΟ </span><span style="color:white; background-color:#e69138">ΕΡΓΟ </span><span style="color:white; background-color:#e69138">ΣΤΗ </span><span style="color:white; background-color:#e69138">ΔΗΜΟΣΙΑ </span><span style="color:white; background-color:#e69138">ΕΚΠΑΙΔΕΥΣΗ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕΧΡΙ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">dd.dd.dddd </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">
#  </span>d. Η <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#a61c00">, </span>ΟΠΩΣ ΑΝΤΙΚΑΤΑΣΤΑΘΗΚΕ ΜΕ ΤΗΝ ΠΑΡ . d ΤΟΥ ΑΡΘΡΟΥ dd ΤΟΥ Ν .   dddd/ dddd , <span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span><span style="color:white; background-color:#b45f06">ΩΣ </span>ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΚΑΘΕ </span><span style="color:white; background-color:#e69138">ΔΙΑΤΑΞΗ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΡΥΘΜΙΖΕΙ </span><span style="color:white; background-color:#e69138">ΔΙΑΦΟΡΕΤΙΚΑ </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΘΕΜΑ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΡΓΕΙΤΑΙ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΕΚΤΟΣ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΣΤΑΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΑΤΑΞΕΩΝ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΦΟΡΕΩΝ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΠΡΟΒΛΕΠΟΥΝ </span><span style="color:white; background-color:#e69138">ΔΙΑΚΟΠΗ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΝΑΣΤΟΛΗ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΒΟΛΗΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΣΥΝΤΑΞΗΣ </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">Ο </span><span style="color:white; background-color:#e69138">ΣΥΝΤΑΞΙΟΥΧΟΣ </span><span style="color:white; background-color:#e69138">ΑΝΑΛΑΜΒΑΝΕΙ </span><span style="color:white; background-color:#e69138">ΕΡΓΑΣΙΑ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΥΤΟΑΠΑΣΧΟΛΕΙΤΑΙ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΥΠΑΓΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΗΝ </span><span style="color:white; background-color:#e69138">ΑΣΦΑΛΙΣΗ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΦΟΡΕΑ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΟΝ </span><span style="color:white; background-color:#e69138">ΟΠΟΙΟ </span><span style="color:white; background-color:#e69138">ΣΥΝΤΑΞΙΟΔΟΤΕΙΤΑΙ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">
#  </span><span style="color:white; background-color:#e69138">ΣΤΙΣ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΠΤΩΣΕΙΣ </span><span style="color:white; background-color:#e69138">ΑΥΤΕΣ </span><span style="color:white; background-color:#e69138">ΔΕΝ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΒΑΛΛΟΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΠΡΟΒΛΕΠΟΜΕΝΕΣ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΠΑΡΑΓΡΑΦΟ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e6
# ΑΡΘΡΟ ddΕΙΔΙΚΟΤΗΤΑ ΨΥΧΙΑΤΡΙΚΗΣ , ΝΕΥΡΟΛΟΓΙΑΣ , ΠΑΙΔΟΨΥΧΙΑΤΡΙΚΗΣ ΚΑΙ ΦΥΣΙΚΗΣ ΙΑΤΡΙΚΗΣ ΚΑΙ ΑΠΟΚΑΤΑΣΤΑΣΗΣ
#  d. Η <span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">   </span><span style="color:white; background-color:#a61c00">dddd/dddd </span>( <span style="color:white; background-color:#5b0f00">ΦΕΚ </span><span style="color:white; background-color:#5b0f00">ddd </span><span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΑΠΟ ΤΗΝ ΕΝΑΡΞΗ ΙΣΧΥΟΣ ΤΗΣ ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΣΚΗΣΗ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΙΑΤΡΩΝ </span><span style="color:white; background-color:#e69138">ΓΙΑ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΑΠΟΚΤΗΣΗ </span><span style="color:white; background-color:#e69138">ΤΙΤΛΟΥ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΙΑΤΡΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΕΙΔΙΚΟΤΗΤΩΝ </span><span style="color:white; background-color:#e69138">ΨΥΧΙΑΤΡΙΚΗΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΝΕΥΡΟΛΟΓΙΑΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΠΑΙΔΟΨΥΧΙΑΤΡΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΦΥΣΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΙΑΤΡΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΑΠΟΚΑΤΑΣΤΑΣΗΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΘΑ </span><span style="color:white; background-color:#e69138">ΠΡΑΓΜΑΤΟΠΟΙΕΙΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΑ </span><span style="color:white; background-color:#e69138">ΝΟΣΟΚΟΜΕΙΑ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΕΧΟΥΝ </span><span style="color:white; background-color:#e69138">ΑΝΑΓΝΩΡΙΣΘΕΙ </span><span style="color:white; background-color:#e69138">ΝΑ </span><span style="color:white; background-color:#e69138">ΧΟΡΗΓΟΥΝ </span><span style="color:white; background-color:#e69138">ΑΣΚΗΣΗ </span><span style="color:white; background-color:#e69138">ΣΤΙΣ </span><span style="color:white; background-color:#e69138">ΕΙΔΙΚΟΤΗΤΕΣ </span><span style="color:white; background-color:#e69138">ΑΥΤΕΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΕΝΙΑΙΑ </span><span style="color:white; background-color:#e69138">ΤΟΠΟΘΕΤΗΣΗ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΣΥΜΠΕΡΙΛΑΜΒΑΝΟΜΕΝΩΝ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΠΡΟΚΑΤΑΡΚΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΣΤΑΔΙΩΝ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΣΚΗΣΗ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΙΑΤΡΩΝ </span><span style="color:white; background-color:#e69138">ΣΤΑ </span><span style="color:white; background-color:#e69138">ΕΠΙ </span><span style="color:white; background-color:#e69138">ΜΕΡΟΥΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΚΥΡΙΑΣ </span><span style="color:white; background-color:#e69138">ΕΙΔΙΚΟΤΗΤΑΣ </span><span style="color:white; background-color:#e69138">ΤΜΗΜΑΤΑ </span><span style="color:white; background-color:#e69138">ΘΑ </span><span style="color:white; background-color:#e69138">ΠΡΑ ...
#  </span>d. Η <span style="color:white; background-color:#ff0000">ΥΠ’ </span><span style="color:white; background-color:#ff0000">ΑΡΙΘΜ. </span>ΥdΑ <span style="color:white; background-color:#a61c00">/ </span><span style="color:white; background-color:#a61c00">Γ.Π.ΟΙΚ </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dd </span><span style="color:white; background-color:#a61c00">dddd/dd </span><span style="color:white; background-color:#a61c00">dd </span>( <span style="color:white; background-color:#5b0f00">ΦΕΚ </span><span style="color:white; background-color:#5b0f00">dddd </span><span style="color:white; background-color:#5b0f00">Β΄ </span><span style="color:white; background-color:#5b0f00">) </span>ΥΠΟΥΡΓΙΚΗ ΑΠΟΦΑΣΗ « ΑΣΚΗΣΗ ΤΩΝ ΙΑΤΡΩΝ ΓΙΑ ΤΗΝ ΑΠΟΚΤΗΣΗ ΤΟΥ ΤΙΤΛΟΥ ΙΑΤΡΙΚΗΣ ΕΙΔΙΚΟΤΗΤΑΣ ΤΗΣ ΝΕΥΡΟΛΟΓΙΑΣ , ΤΗΣ ΨΥΧΙΑΤΡΙΚΗΣ ΚΑΙ ΛΟΙΠΕΣ ΕΙΔΙΚΟΤΗΤΕΣ » ΚΑΤΑΡΓΕΙΤΑΙ ΑΠΟ ΤΗΝ ΕΝΑΡΞΗ ΙΣΧΥΟΣ ΤΗΣ .
#  d. ΜΕΤΑΒΑΤΙΚΕΣ ΔΙΑΤΑΞΕΙΣ : ΟΛΟΙ ΟΙ ΙΑΤΡΟΙ ΤΩΝ ΟΠΟΙΩΝ ΟΙ ΑΙΤΗΣΕΙΣ ΓΙΑ ΕΙΔΙΚΕΥΣΗ ΕΚΚΡΕΜΟΥΣΑΝ ΚΑΤΑ ΤΙΣ d.d.dddd ΣΤΑ ΚΥΡΙΑ ΣΤΑΔΙΑ ΤΩΝ ΕΙΔΙΚΟΤΗΤΩΝ ΨΥΧΙΑΤΡΙΚΗΣ , ΝΕΥΡΟΛΟΓΙΑΣ , ΠΑΙΔΟΨΥΧΙΑΤΡΙΚΗΣ ΚΑΙ ΦΥΣΙΚΗΣ ΙΑΤΡΙΚΗΣ ΚΑΙ ΑΠΟΚΑΤΑΣΤΑΣΗΣ ΘΑ ΤΟΠΟΘΕΤΗΘΟΥΝ ΓΙΑ ΣΥΝΕΧΙΣΗ ΤΗΣ ΕΙΔΙΚΕΥΣΗΣ ΤΟΥΣ ΣΥΜΦΩΝΑ ΜΕ ΤΗΝ ΗΜΕΡΟΜΗΝΙΑ ΥΠΟΒΟΛΗΣ ΤΩΝ ΑΙΤΗΣΕΩΝ ΤΟΥΣ ΣΤΟ ΠΡΟΗΓΟΥΜΕΝΟ ΣΤΑΔΙΟ ΕΙΔΙΚΕΥΣΗΣ . ΟΠΟΥ ΤΟ ΠΡΟΗΓΟΥΜΕΝΟ ΣΤΑΔΙΟ ΠΡΑΓΜΑΤΟΠΟΙΗΘΗΚΕ ΣΕ ΠΕΡΙΣΣΟΤΕΡΑ ΤΟΥ ΕΝΟΣ ΜΕΡΗ , ΘΑ ΛΗΦΘΕΙ ΥΠΟΨΗ Η ΗΜΕΡΟΜΗΝΙΑ ΥΠΟΒΟΛΗΣ ΤΗΣ ΑΙΤΗΣΗΣ ΣΤΟ ΠΡΩΤΟ ΜΕΡΟΣ ΤΟΥ ΣΤΑΔΙΟΥ ΑΥΤΟΥ . ΑΝΑ ΔΕΚΑΠΕΝΤΕ ΕΡΓΑΣΙΜΕΣ ΗΜΕΡΕΣ ΑΠΟ ΔΗΜΟΣΙΕΥΣΕΩΣ ΤΟΥ ΠΑΡΟΝΤΟΣ , ΘΑ ΥΠΟΒΑΛΛΟΥΝ ΑΙΤΗΣΕΙΣ , ΣΤΙΣ ΑΡΜΟΔΙΕΣ ΠΕΡΙΦΕΡΕΙΑΚΕΣ ΑΥΤΟΔΙΟΙΚΗΣΕΙΣ , ΠΡΟΚΕΙΜΕΝΟΥ ΝΑ ΛΑΒΟΥΝ ΣΕΙΡΑ ΠΡΟΤΕΡΑΙΟΤΗΤΑΣ ΣΤΗΝ ΚΥΡΙΑ ΕΙΔΙΚΟΤΗΤΑ , ΓΙΑ ΕΝΙΑΙΑ ΤΟΠΟΘΕΤΗΣΗ :
#  Α ) ΟΙ ΙΑΤΡΟΙ ΠΟΥ ΟΙ ΑΙΤΗΣΕΙΣ ΤΟΥΣ ΕΚΚΡΕΜΟΥΣΑΝ ΓΙΑ ΕΙΔΙΚΕΥΣ
# ΑΡΘΡΟ dΤΡΟΠΟΠΟΙΗΣΗ ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Ν . dddd/dddd
#  d. Η <span style="color:white; background-color:#ff0000">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#ff0000">Α΄ </span><span style="color:white; background-color:#ff0000">ΤΗΣ </span><span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/ </span><span style="color:white; background-color:#a61c00">dddd </span>( <span style="color:white; background-color:#5b0f00">ΦΕΚ </span><span style="color:white; background-color:#5b0f00">ddd </span><span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">Α </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΟΠΛΟ </span><span style="color:white; background-color:#e69138">ΕΙΝΑΙ </span><span style="color:white; background-color:#e69138">ΚΑΘΕ </span><span style="color:white; background-color:#e69138">ΜΗΧΑΝΗΜΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΟΠΟΙΟ </span><span style="color:white; background-color:#e69138">ΕΚ </span><span style="color:white; background-color:#e69138">ΚΑΤΑΣΚΕΥΗΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕΤΑΤΡΟΠΗΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΤΡΟΠΟΠΟΙΗΣΗΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΩΣΤΙΚΗ </span><span style="color:white; background-color:#e69138">ΔΥΝΑΜΗ </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΠΑΡΑΓΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΟΠΟΙΟΝΔΗΠΟΤΕ </span><span style="color:white; background-color:#e69138">ΤΡΟΠΟ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΕΚΤΟΞΕΥΕΙ </span><span style="color:white; background-color:#e69138">ΒΛΗΜΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΒΛΑΠΤΙΚΕΣ </span><span style="color:white; background-color:#e69138">ΧΗΜΙΚΕΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΛΛΕΣ </span><span style="color:white; background-color:#e69138">ΟΥΣΙΕΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΑΚΤΙΝΕΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΦΛΟΓΕΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΕΡΙΑ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΜΠΟΡΕΙ </span><span style="color:white; background-color:#e69138">ΝΑ </span><span style="color:white; background-color:#e69138">ΕΠΙΦΕΡΕΙ </span><span style="color:white; background-color:#e69138">ΚΑΚΩΣΗ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΒΛΑΒΗ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΥΓΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΠΡΟΣΩΠΑ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΒΛΑΒΗ </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΠΡΑΓΜΑΤΑ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΝΑ </span><span style="color:white; background-color:#e69138">ΠΡΟΚΑΛΕΣΕΙ </span><span style="color:white; background-color:#e69138">ΠΥΡΚΑΓΙΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΟΠΩΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span  ...
# ΑΡΘΡΟ ddd
#  d. Η <span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟΣ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span>( <span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">ddd </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΕΚΤΟΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΔΥΝΑΤΟΤΗΤΑΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΑΥΤΕΠΑΓΓΕΛΤΗΣ </span><span style="color:white; background-color:#e69138">ΚΙΝΗΣΗΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΔΙΑΔΙΚΑΣΙΑΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΟΠΟΙΟΣ </span><span style="color:white; background-color:#e69138">ΕΝΔΙΑΦΕΡΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΓΙΑ </span><span style="color:white; background-color:#e69138">ΤΟΝ </span><span style="color:white; background-color:#e69138">ΚΑΘΟΡΙΣΜΟ </span><span style="color:white; background-color:#e69138">ΑΙΓΙΑΛΟΥ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΠΑΡΑΛΙΑΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΑΠΕΥΘΥΝΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΗΝ </span><span style="color:white; background-color:#e69138">ΑΡΜΟΔΙΑ </span><span style="color:white; background-color:#e69138">ΚΤΗΜΑΤΙΚΗ </span><span style="color:white; background-color:#e69138">ΥΠΗΡΕΣΙΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΟΠΟΙΑ </span><span style="color:white; background-color:#e69138">ΜΕΣΑ </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΠΕΝΤΕ </span><span style="color:white; background-color:#e69138">( </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">) </span><span style="color:white; background-color:#e69138">ΗΜΕΡΕΣ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΥΠΟΒΟΛΗ </span><span style="color:white; background-color:#e69138">ΣΧΕΤΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΑΙΤΗΣΗΣ </span><span style="color:white; background-color:#e69138">ΕΝΗΜΕΡΩΝΕΙ </span><span style="color:white; background-color:#e69138">ΤΟΝ </span><span style="color:white; background-color:#e69138">ΕΝΔΙΑΦΕΡΟΜΕΝΟ </span><span style="color:white; background-color:#e69138">ΑΝ </span><span style="color:white; background-color:#e69138">ΕΧΕΙ </span><span style="color:white; background-color:#e69138">ΗΔΗ </span><span style="color:white; background-color:#e69138">ΓΙΝΕΙ </span><span style="color:white; background-color:#e69138">ΚΑΘΟΡΙΣΜΟΣ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΔΕΝ </span><span style="color:white; background-color:#e69138">ΕΧΕΙ </span><span style="color:white; background-color:#e69138">ΓΙΝΕΙ </span><span style="color:white; background-color:#e69138">Ο </span><span style="color:white; background-color:#e69138">ΚΑΘΟΡΙΣΜΟΣ </span><span style="color:white; background-color:#e69138">ΑΙΓΙΑΛΟΥ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; backgr ...
# ΑΡΘΡΟ dd
#  ΤΟ <span style="color:white; background-color:#ff0000">ΑΡΘΡΟ </span><span style="color:white; background-color:#ff0000">ddd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Π.Δ. </span><span style="color:white; background-color:#a61c00">ddd/dddd </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟ </span><span style="color:white; background-color:#e69138">dddΤΕΛΩΝΕΙΑ </span><span style="color:white; background-color:#e69138">
#  </span><span style="color:white; background-color:#e69138">d. </span><span style="color:white; background-color:#e69138">ΣΤΟ </span><span style="color:white; background-color:#e69138">ΝΟΜΟ </span><span style="color:white; background-color:#e69138">ΤΡΙΚΑΛΩΝ </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΑΡΜΟΔΙΟΤΗΤΕΣ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΑΣΚΟΥΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΤΕΛΩΝΕΙΟ </span><span style="color:white; background-color:#e69138">ΤΡΙΚΑΛΩΝ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">
#  </span><span style="color:white; background-color:#e69138">d. </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΤΕΛΩΝΕΙΟ </span><span style="color:white; background-color:#e69138">ΤΡΙΚΑΛΩΝ </span><span style="color:white; background-color:#e69138">ΕΙΝΑΙ </span><span style="color:white; background-color:#e69138">Β΄ </span><span style="color:white; background-color:#e69138">ΤΑΞΗΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΕΧΕΙ </span><span style="color:white; background-color:#e69138">ΕΔΡΑ </span><span style="color:white; background-color:#e69138">ΤΑ </span><span style="color:white; background-color:#e69138">ΤΡΙΚΑΛΑ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΚΑΤΑ </span><span style="color:white; background-color:#e69138">ΤΟΠΟΝ </span><span style="color:white; background-color:#e69138">ΑΡΜΟΔΙΟΤΗΤΑ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΚΤΕΙΝΕΤΑΙ </span><span style="color:white; background-color:#e69138">Σ’ </span><span style="color:white; background-color:#e69138">ΟΛΟΚΛΗΡΟ </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΝΟΜΟ </span><span style="color:white; background-color:#e69138">ΤΡΙΚΑΛΩΝ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">» </span>
# ΑΡΘΡΟ ddΣΙΤΙΣΗ ΚΑΙ ΣΤΕΓΑΣΗ ΦΟΙΤΗΤΩΝ ΜΕΣΩ ΤΟΥ Ε.Ι.Ν .
#  Η <span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟΣ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span>( <span style="color:white; background-color:#5b0f00">ΦΕΚ </span><span style="color:white; background-color:#5b0f00">dd </span><span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">Α </span><span style="color:white; background-color:#e69138">) </span><span style="color:white; background-color:#e69138">ΓΙΑ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΚΑΛΥΨΗ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΔΑΠΑΝΗΣ </span><span style="color:white; background-color:#e69138">ΣΙΤΙΣΗΣ </span><span style="color:white; background-color:#e69138">ΠΡΟΠΤΥΧΙΑΚΩΝ </span><span style="color:white; background-color:#e69138">ΦΟΙΤΗΤΩΝ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΣΠΟΥΔΑΣΤΩΝ </span><span style="color:white; background-color:#e69138">ΕΓΓΡΑΦΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΚΑΘΕ </span><span style="color:white; background-color:#e69138">ΧΡΟΝΟ </span><span style="color:white; background-color:#e69138">ΣΤΟΝ </span><span style="color:white; background-color:#e69138">ΠΡΟΥΠΟΛΟΓΙΣΜΟ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΥΠΟΥΡΓΕΙΟΥ </span><span style="color:white; background-color:#e69138">ΕΘΝΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΙΔΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΘΡΗΣΚΕΥΜΑΤΩΝ </span><span style="color:white; background-color:#e69138">ΕΙΔΙΚΗ </span><span style="color:white; background-color:#e69138">ΠΙΣΤΩΣΗ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΟΠΟΙΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΑΠΟΦΑΣΗ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΥΠΟΥΡΓΟΥ </span><span style="color:white; background-color:#e69138">ΕΘΝΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΙΔΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΘΡΗΣΚΕΥΜΑΤΩΝ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΕΠΙΧΟΡΗΓΟΥΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΕΘΝΙΚΟ </span><span style="color:white; background-color:#e69138">ΙΔΡΥΜΑ </span><span style="color:white; background-color:#e69138">ΝΕΟΤΗΤΟΣ </span><span style="color:white; background-color:#e69138">( </span><span style="color:white; background-color:#e69138">Ε.Ι.Ν </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">) </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΤΑ </span><span style="color:white; background-color:#e69138">ΠΑΝΕΠΙΣΤΗΜΙΑ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΤΑ </span><span style="color:white; background-color:#e69138">Τ.Ε.Ι. </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΦΟΙΤΗΤΙΚΕΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; backgrou ...
# ΄ΑΡΘΡΟ ddΤΡΟΠΟΠΟΙΗΣΗ ΔΙΑΤΑΞΕΩΝ
#  d. ΣΤΗΝ <span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Π.Δ. </span><span style="color:white; background-color:#a61c00">dd/dddd </span>( <span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">dd </span><span style="color:white; background-color:#5b0f00">) </span>, ΟΠΩΣ ΑΥΤΗ ΑΝΤΙΚΑΤΑΣΤΑΘΗΚΕ ΜΕ ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. dd/dddd ( Α΄ dd ) ΚΑΙ ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. d/dddd ( Α΄ d) , <span style="color:white; background-color:#b45f06">ΠΡΟΣΤΙΘΕΤΑΙ </span><span style="color:white; background-color:#0000ff">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#0000ff">ΙΕ΄ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">ΙΕ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΥΠΗΡΕΣΙΑ </span><span style="color:white; background-color:#e69138">ΟΙΚΟΝΟΜΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΑΣΤΥΝΟΜΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΔΙΩΞΗΣ </span><span style="color:white; background-color:#e69138">ΗΛΕΚΤΡΟΝΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΕΓΚΛΗΜΑΤΟΣ </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">. </span>
#  d. Η <span style="color:white; background-color:#ff0000">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#ff0000">Α΄ </span><span style="color:white; background-color:#ff0000">ΤΗΣ </span><span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟΥ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΙΔΙΟΥ </span><span style="color:white; background-color:#ff0000">Π.Δ. </span><span style="color:white; background-color:#ff0000">, </span>ΟΠΩΣ ΑΝΤΙΚΑΤΑΣΤΑΘΗΚΕ ΜΕ ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. ddd/dddd ( Α΄ ddd ) , ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. ddd/dddd ( Α΄ ddd ) , ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. ddd/dddd ( Α΄ ddd ) ΚΑΙ ΤΗΝ ΠΑΡΑΓΡΑΦΟ d ΤΟΥ ΑΡΘΡΟΥ d ΤΟΥ Π.Δ. d/dddd ( Α΄ d) , <span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">Α </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΥΠΗΡΕΣΙΕΣ </span><span style="color:white; background-color:#e69138">ΑΣΦΑΛΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΠΡΟΕΔΡΟΥ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΔΗΜΟΚΡΑΤΙΑΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΒΟΥΛΗΣ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΕΛΛΗΝΩΝ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΟΙΚΟΝΟΜΙΚΗΣ </span><span style="color:white; background-color:#e69138">ΑΣΤΥΝΟΜΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΔΙΩΞΗΣ </span><span style="color:white; background-color:#e69138">ΗΛΕΚΤΡΟΝΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΕΓΚΛΗΜΑΤΟΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΚΑΘΩΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΔΙΕΥΘΥΝΣΕΙΣ </span><span style="color:white; background-color:#e69138">ΕΣΩΤΕΡΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΥΠΟΘΕΣΕΩΝ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΑΝΤΙΜΕΤΩΠΙΣΗΣ </span><span style="color:white; background-color:#e69138">ΕΙΔΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΕΓΚΛΗΜΑΤΩΝ </span><span style="color:white; background-color:#e69138">ΒΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΕΓΚΛΗΜΑΤΟΛΟΓΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΕΡΕΥΝΩΝ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΟΝ </span><span style="color:white; background-color:#e69138">ΑΡΧΗΓΟ </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">. </span>
# ΑΡΘΡΟ dd
#  d. ΤΟ <span style="color:white; background-color:#ff0000">ΠΡΩΤΟ </span><span style="color:white; background-color:#ff0000">ΕΔΑΦΙΟ </span><span style="color:white; background-color:#ff0000">ΤΗΣ </span><span style="color:white; background-color:#ff0000">ΠΑΡ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Π.Δ. </span><span style="color:white; background-color:#a61c00">  </span><span style="color:white; background-color:#a61c00">dd/dddd </span>( <span style="color:white; background-color:#5b0f00">Α?dd </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΑΚΟΛΟΥΘΩΣ :
# ...
# ΑΡΘΡΟ dd
#  d. ΣΤΟ ΑΡΘΡΟ <span style="color:white; background-color:#ff0000">dd </span>ΤΟΥ <span style="color:white; background-color:#ff0000">ΚΩΔΙΚΑ </span>ΤΟΥ <span style="color:white; background-color:#ff0000">ΠΡΟΣΩΠΙΚΟΥ </span>ΛΙΜΕΝΙΚΟΥ <span style="color:white; background-color:#ff0000">ΣΩΜΑΤΟΣ </span>( Κ.Π.Λ.Σ . ) , Ο ΟΠΟΙΟΣ ΚΥΡΩΘΗΚΕ ΜΕ ΤΟ Ν <span style="color:white; background-color:#a61c00">. </span>dddd/dddd ( ΦΕΚ ddd Α ) <span style="color:white; background-color:#b45f06">ΠΡΟΣΤΙΘΕΤΑΙ </span><span style="color:white; background-color:#0000ff">ΠΑΡΑΓΡΑΦΟΣ </span><span style="color:white; background-color:#0000ff">d </span>ΩΣ ΑΚΟΛΟΥΘΩΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΟΙ </span><span style="color:white; background-color:#e69138">ΘΕΣΕΙΣ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΑΡΧΙΠΛΟΙΑΡΧΩΝ </span><span style="color:white; background-color:#e69138">Λ.Σ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΔΑΦΙΟΥ </span><span style="color:white; background-color:#e69138">ΑΑ </span><span style="color:white; background-color:#e69138">’ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΠΕΡΙΠΤΩΣΗΣ </span><span style="color:white; background-color:#e69138">Α </span><span style="color:white; background-color:#e69138">’ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΡΑΓΡΑΦΟΥ </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#e69138">dd </span><span style="color:white; background-color:#e69138">ΑΥΞΑΝΟΝΤΑΙ </span><span style="color:white; background-color:#e69138">ΚΑΤΑ </span><span style="color:white; background-color:#e69138">ΜΙΑ </span><span style="color:white; background-color:#e69138">ΜΕΙΟΥΜΕΝΩΝ </span><span style="color:white; background-color:#e69138">ΑΝΑΛΟΓΙΚΑ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΤΑΥΤΟΣΗΜΟ </span><span style="color:white; background-color:#e69138">ΑΡΙΘΜΟ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΘΕΣΕΩΝ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΑΝΤΙΠΛΟΙΑΡΧΩΝ </span><span style="color:white; background-color:#e69138">Λ.Σ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΙΔΙΑΣ </span><span style="color:white; background-color:#e69138">ΚΑΤΗΓΟΡΙΑΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΗΤΟΙ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΠΡΟΕΡΧΟΜΕΝΩΝ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ΣΧΟΛΗ </span><span style="color:white; background-color:#e69138">ΔΟΚΙΜΩΝ </span><span style="color:white; background-color:#e69138">ΣΗΜΑΙΟΦΟΡΩΝ </span><span style="color:white; background-color:#e69138">Λ.Σ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">» </span><span style="color:white; background-color:#e69138">. </span>
#  d. Η <span style="color:white; background-color:#ff0000">ΠΕΡΙΠΤΩΣΗ </span><span style="color:white; background-color:#ff0000">Α΄ </span><span style="color:white; background-color:#ff0000">ΤΗΣ </span><span style="color:white; background-color:#ff0000">ΠΑΡΑΓΡΑΦΟΥ </span><span style="color:white; background-color:#ff0000">d </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">ΑΡΘΡΟΥ </span><span style="color:white; background-color:#ff0000">dd </span><span style="color:white; background-color:#ff0000">ΤΟΥ </span><span style="color:white; background-color:#ff0000">Κ.Π.Λ.Σ </span><span style="color:white; background-color:#ff0000">. </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΑΚΟΛΟΥΘΩΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">Α </span><span style="color:white; background-color:#e69138">) </span><span style="color:white; background-color:#e69138">ΑΝΘΥΠΑΣΠΙΣΤΕΣ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΥΠΑΞΙΩΜΑΤΙΚΟΙ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΠΟΥ </span><span style="color:white; background-color:#e69138">ΕΞΗΛΘΑΝ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗ </span><span style="color:white; background-color:#e69138">ΣΧΟΛΗ </span><span style="color:white; background-color:#e69138">ΔΟΚΙΜΩΝ </span><span style="color:white; background-color:#e69138">ΥΠΑΞΙΩΜΑΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">Λ.Σ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">ΠΡΙΝ </span><span style="color:white; background-color:#e69138">ΑΠΟ </span><span style="color:white; background-color:#e69138">ΤΗ </span><span style="color:white; background-color:#e69138">ddΗ </span><span style="color:white; background-color:#e69138">ΙΟΥΛΙΟΥ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΤΟΥΣ </span><span style="color:white; background-color:#e69138">dddd </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΚΑΤΕΧΟΥΝ </span><span style="color:white; background-color:#e69138">ΠΤΥΧΙΟ </span><span style="color:white; background-color:#e69138">ΙΔΡΥΜΑΤΟΣ </span><span style="color:white; background-color:#e69138">ΑΝΩΤΑΤΗΣ </span><span style="color:white; background-color:#e69138">ΕΚΠΑΙΔΕΥΣΗΣ </span><span style="color:white; background-color:#e69138">ΠΑΝΕΠΙΣΤΗΜΙΑΚΟΥ </span><span style="color:white; background-color:#e69138">ΤΟΜΕΑ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΔΙΠΛΩΜΑ </span><span style="color:white; background-color:#e69138">ΠΛΟΙΑΡΧΟΥ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΜΗΧΑΝΙΚΟΥ </span><span style="color:white; background-color:#e69138">Γ΄ </span><span style="color:white; background-color:#e69138">ΤΑΞΕΩΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΡΑΔΙΟΤΗΛΕΓΡΑΦΗΤΗ </span><span style="color:white; background-color:#e69138">Β΄ </span><span style="color:white; background-color:#e69138">ΤΑΞΕΩΣ </span><span style="color:white; background-color:#e69138">ΕΜΠΟΡΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΝΑΥΤΙΚΟΥ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e6913
# ΑΡΘΡΟ dΘΕΜΑΤΑ ΔΙΚΑΣΤΙΚΩΝ ΛΕΙΤΟΥΡΓΩΝΔΙΟΙΚΗΤΙΚΗΣ ΔΙΚΑΙΟΣΥΝΗΣ
#  d. ΤΟ <span style="color:white; background-color:#ff0000">ΑΡΘΡΟ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span>( <span style="color:white; background-color:#5b0f00">ΦΕΚ </span><span style="color:white; background-color:#5b0f00">ddd </span><span style="color:white; background-color:#5b0f00">Α΄ </span><span style="color:white; background-color:#5b0f00">) </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">ΣΕ </span><span style="color:white; background-color:#e69138">ΣΥΜΒΟΥΛΟ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΕΠΙΚΡΑΤΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΠΡΟΑΓΕΤΑΙ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΣΥΜΦΩΝΑ </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΤΑ </span><span style="color:white; background-color:#e69138">ΟΡΙΖΟΜΕΝΑ </span><span style="color:white; background-color:#e69138">ΣΤΟ </span><span style="color:white; background-color:#e69138">ΑΡΘΡΟ </span><span style="color:white; background-color:#e69138">dd </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΕΦΟΣΟΝ </span><span style="color:white; background-color:#e69138">ΔΕΝ </span><span style="color:white; background-color:#e69138">ΣΥΜΠΛΗΡΩΝΕΙ </span><span style="color:white; background-color:#e69138">ΤΟ </span><span style="color:white; background-color:#e69138">ΕΞΗΚΟΣΤΟ </span><span style="color:white; background-color:#e69138">ΤΡΙΤΟ </span><span style="color:white; background-color:#e69138">ΕΤΟΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΗΛΙΚΙΑΣ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΩΣ </span><span style="color:white; background-color:#e69138">ΤΗΝ </span><span style="color:white; background-color:#e69138">ddΗ </span><span style="color:white; background-color:#e69138">ΔΕΚΕΜΒΡΙΟΥ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΤΟΥΣ </span><span style="color:white; background-color:#e69138">ΚΕΝΩΣΕΩΣ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΣΥΣΤΑΣΕΩΣ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΘΕΣΕΩΣ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΠΡΟΕΔΡΟΣ </span><span style="color:white; background-color:#e69138">ΕΦΕΤΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΟΙΚΗΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΗΡΙΩΝ </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΕΦΕΤΗΣ </span><span style="color:white; background-color:#e69138">ΔΙΟΙΚΗΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΗΡΙΩΝ </span><span style="color:white; background-color:#e69138">, </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΕΠΤΑ </span><span style="color:white; background-color:#e69138">ΤΟΥΛΑΧΙΣΤΟΝ </span><span style="color:white; background-color:#e69138">ΕΤΗ </span><span style="color:white; background-color:#e69138">ΥΠΗΡΕΣΙΑΣ </span><span style="color:white; background-color:#e69138">ΣΤΟ </span><span style="color:white; background-color:#e69138">ΒΑΘΜΟ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΕΦΕΤΗ </span><span style="color:white; background-color:#e69138">ΚΑΙ </span><span style="color:white; background-color:#e69138">ΣΥΝΟΛΙΚΗ </span><span style="color:white; background-color:#e69138">ΠΡΑΓΜΑΤΙΚΗ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΙΚΗ </span><span style="color:white; background-color:#e69138">ΥΠΗΡΕΣΙΑ </span><span style="color:white; background-color:#e69138">ΕΙΚΟΣΙ </span><span style ...
#  d. ΤΟ <span style="color:white; background-color:#ff0000">ΑΡΘΡΟ </span><span style="color:white; background-color:#ff0000">d </span>ΤΟΥ <span style="color:white; background-color:#a61c00">Ν </span><span style="color:white; background-color:#a61c00">. </span><span style="color:white; background-color:#a61c00">dddd/dddd </span><span style="color:white; background-color:#b45f06">ΑΝΤΙΚΑΘΙΣΤΑΤΑΙ </span>ΩΣ ΕΞΗΣ :
#  <span style="color:white; background-color:#e69138">« </span><span style="color:white; background-color:#e69138">d </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΔΙΑΔΙΚΑΣΙΑ </span><span style="color:white; background-color:#e69138">ΠΛΗΡΩΣΗΣ </span><span style="color:white; background-color:#e69138">ΘΕΣΕΩΣ </span><span style="color:white; background-color:#e69138">ΣΥΜΒΟΥΛΟΥ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΕΠΙΚΡΑΤΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΠΡΟΑΓΩΓΗ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΗ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΤΑΚΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΟΙΚΗΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΗΡΙΩΝ </span><span style="color:white; background-color:#e69138">ΚΙΝΕΙΤΑΙ </span><span style="color:white; background-color:#e69138">ΜΕ </span><span style="color:white; background-color:#e69138">ΑΝΑΚΟΙΝΩΣΗ </span><span style="color:white; background-color:#e69138">ΤΟΥ </span><span style="color:white; background-color:#e69138">ΓΕΝΙΚΟΥ </span><span style="color:white; background-color:#e69138">ΕΠΙΤΡΟΠΟΥ </span><span style="color:white; background-color:#e69138">ΤΗΣ </span><span style="color:white; background-color:#e69138">ΕΠΙΚΡΑΤΕΙΑΣ </span><span style="color:white; background-color:#e69138">ΤΩΝ </span><span style="color:white; background-color:#e69138">ΤΑΚΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΟΙΚΗΤΙΚΩΝ </span><span style="color:white; background-color:#e69138">ΔΙΚΑΣΤΗΡΙΩΝ </span><span style="color:white; background-color:#e69138">. </span><span style="color:white; background-color:#e69138">Η </span><span style="color:white; background-color:#e69138">ΑΝΑΚΟΙΝΩΣΗ </span><span style="color:white; background-color:#e69138">ΑΠΟΣΤΕΛΛΕΤΑΙ </span><span style="color:white; background-color:#e69138">ΣΤΑ </span><span style="color:white; background-color:#e69138">ΔΙΟΙΚΗΤΙΚΑ </span><span style="color:white;

# %%
errors=list()
for i in range(len(pred_labels)):
    errors.append(sum([1 for j in range(min(input_length, len(toks[train_size+i]['labels']))) if pred_labels[i][j]!= np.argmax(y_test[i][j])]))

# %%
print(errors)
errors.index(max(errors))

# %%
with open('output/batch_size_128.pickle','rb') as f:
    p=pickle.load(f)
with open('output/batch_size_128.csv','w') as f:
    c=csv.writer(f)
    c.writerows(p)

# %%
with open('output/batch_size_epochs.csv','r') as f:
    c=csv.reader(f)
    l=list(c)
    for i in l:
        print(i)

# %%
[j[3] for j in [i for i in l if i[0]=='10']]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle
import csv
import numpy as np
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for z in [10,50,100]:
    ax.bar([1,2,3,4,5], [j[3] for j in [i for i in l if i[0]==str(z)]], zs=z, zdir='y')
plt.show()
